# %% [markdown]
# <h1> Muhammaad Fachrul Rozy </h1>
# <h2> 2009106091 </h2>
# <h2> POSTTEST 6 </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


from sklearn.impute import SimpleImputer

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("players.csv")

# %%
df
# Out:
#           name_pais            name         tag  rank  expLevel  trophies  \
# 0       Afghanistan            f34r  #2UQ99VLU2     1        13      6148
# 1       Afghanistan      Ķìňğ Ãìmãĺ    #QJRU92L     2        13      6005
# 2       Afghanistan   L☯️I☯️Y☯️A☯️M  #800CLLPU8     3        13      5988
# 3       Afghanistan  FRAIDOON ISHAQ   #9LLLJP8C     4        13      5920
# 4       Afghanistan   ⚡king behzad⚡  #P9VLCU8Y9     5        13      5912
# ...             ...             ...         ...   ...       ...       ...
# 167228     Zimbabwe      SethyPlayz  #QQ2U8JCP8   397         2        30
# 167229     Zimbabwe        kingkong  #R0G2RYCJ2   398         2        30
# 167230     Zimbabwe   Lord Gargamel  #Y8Y2Y0PV0   399         2        29
# 167231     Zimbabwe          mattm8  #J089J0YCG   400         2        29
# 167232     Zimbabwe          sipoko  #R2U8RG0R8   401         2        28
#
#           name_clan   tag_clan  id_arena      name_arena
# 0          PhatKatz    #G9LGQR  54000015        Master I
# 1        God of War   #V2RUJ88  54000015        Master I
# 2        اسیرسرنوشت  #L2CC2L9C  54000015        Master I
# 3       Afghanistan  #PGV80J0P  54000014  Challenger III
# 4       Delta Force  #LR8P9L8C  54000014  Challenger III
# ...             ...        ...       ...             ...
# 167228          NaN        NaN  54000001         Arena 1
# 167229          NaN        NaN  54000001         Arena 1
# 167230          NaN        NaN  54000001         Arena 1
# 167231         join  #YRUUY0C0  54000001         Arena 1
# 167232          NaN        NaN  54000001         Arena 1
#
# [167233 rows x 10 columns]

# %%
df2 = pd.read_csv("games.csv")
# Out:
# C:\Users\GEFORCE_i5\AppData\Local\Temp\ipykernel_7000\3967979458.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("games.csv")

# %%
df2
# Out:
#                         team_name  game_num        date     site  \
# 0      Abilene Christian Wildcats         1  2013-11-09     Away
# 1      Abilene Christian Wildcats         2  2013-11-11     Away
# 2      Abilene Christian Wildcats         3  2013-11-13     Away
# 3      Abilene Christian Wildcats         4  2013-11-17     Away
# 4      Abilene Christian Wildcats         5  2013-11-19     Away
# ...                           ...       ...         ...      ...
# 90963   Youngstown State Penguins        28  2018-02-14     Home
# 90964   Youngstown State Penguins        29  2018-02-16     Home
# 90965   Youngstown State Penguins        30  2018-02-19     Away
# 90966   Youngstown State Penguins        31  2018-02-24     Home
# 90967   Youngstown State Penguins        32  2018-03-02  Neutral
#
#                 opp_name w_l pts  opp_pts  fg  fga  ...  opp_ft  opp_fta  \
# 0               Duquesne   L  75       94  22   63  ...    27.0   37.000
# 1        St. Bonaventure   L  47       75  14   40  ...    23.0   32.000
# 2               Maryland   L  44       67  17   54  ...    17.0    0.647
# 3                   Iowa   L  41      103  14   54  ...    18.0   22.000
# 4                    TCU   L  64       71  19   50  ...    24.0   37.000
# ...                  ...  ..  ..      ...  ..  ...  ...     ...      ...
# 90963            Oakland   W  75       73  27   66  ...     8.0   10.000
# 90964            Detroit   L  84       94  32   64  ...    24.0   25.000
# 90965  Northern Kentucky   L  51       70  20   60  ...    17.0   23.000
# 90966    Cleveland State   L  94       99  35   84  ...    20.0   30.000
# 90967    Cleveland State   L  71       72  26   62  ...    18.0   27.000
#
#        opp_ft_per  opp_orb  opp_trb  opp_ast  opp_stl  opp_blk  opp_tov  \
# 0           0.730     10.0     40.0     19.0      4.0      2.0     10.0
# 1           0.719     18.0     40.0     15.0      7.0      7.0      9.0
# 2          12.000     38.0     12.0      9.0     10.0     17.0      8.0
# 3           0.818      5.0     35.0     25.0     11.0      5.0      5.0
# 4           0.649      8.0     30.0     11.0      7.0      3.0      6.0
# ...           ...      ...      ...      ...      ...      ...      ...
# 90963       0.800     12.0     37.0     12.0      3.0      9.0     18.0
# 90964       0.960      6.0     26.0     16.0     10.0      2.0      8.0
# 90965       0.739      8.0     36.0     16.0      6.0      5.0     14.0
# 90966       0.667     10.0     40.0     18.0      5.0      3.0     18.0
# 90967       0.667     10.0     30.0     13.0      8.0      3.0     14.0
#
#        opp_pf
# 0        22.0
# 1        23.0
# 2         NaN
# 3        10.0
# 4        20.0
# ...       ...
# 90963    16.0
# 90964    17.0
# 90965    16.0
# 90966    22.0
# 90967    20.0
#
# [90968 rows x 40 columns]

# %%
df3 = pd.read_csv('use-of-force.csv')

# %%
df3
# Out:
#                             ID  Incident_Num           Incident_Type  \
# 0      2020UOF-1391-2534-22992         56962  Level 1 - Use of Force
# 1      2020UOF-1392-2853-22992         56995  Level 1 - Use of Force
# 2      2020UOF-1393-1194-22992         56961  Level 1 - Use of Force
# 3        2014UOF-0001-1377-203           251  Level 1 - Use of Force
# 4        2014UOF-0002-1098-166           218  Level 1 - Use of Force
# ...                        ...           ...                     ...
# 11550  2020UOF-1395-2229-22994         56959  Level 1 - Use of Force
# 11551  2020UOF-1396-1291-21869         54812  Level 2 - Use of Force
# 11552  2020UOF-1397-1259-21869         54799  Level 2 - Use of Force
# 11553  2020UOF-1398-2179-21869         54797  Level 2 - Use of Force
# 11554  2020UOF-1399-2751-22431         56056  Level 1 - Use of Force
#
#              Occured_date_time Precinct   Sector Beat  Officer_ID  Subject_ID  \
# 0      2020-07-16T01:30:00.000        -      NaN    -        4773       23873
# 1      2020-07-16T00:15:00.000        -      NaN    -        5615       23873
# 2      2020-07-16T00:15:00.000        -      NaN    -        1780       23873
# 3      2014-06-07T00:09:00.000     East  CHARLIE   C2        1594         203
# 4      2014-05-30T14:06:00.000     East   GEORGE   G1        1673         166
# ...                        ...      ...      ...  ...         ...         ...
# 11550  2020-07-16T00:15:00.000        -      NaN    -        2206       23875
# 11551  2020-04-05T15:02:00.000        -      NaN    -        1758       22753
# 11552  2020-04-05T15:00:00.000        -      NaN    -        1750       22753
# 11553  2020-04-05T15:02:00.000        -      NaN    -        2175       22753
# 11554  2020-05-19T00:00:00.000        -      NaN    -        5304       23314
#
#                     Subject_Race Subject_Gender
# 0                          White         Female
# 1                          White         Female
# 2                          White         Female
# 3      Black or African American           Male
# 4                          White           Male
# ...                          ...            ...
# 11550              Not Specified         Female
# 11551              Not Specified           Male
# 11552              Not Specified           Male
# 11553              Not Specified           Male
# 11554  Black or African American           Male
#
# [11555 rows x 11 columns]

# %% [markdown]
# # Data Cleaning

# %%
dataset_ns1 = df.copy()
dataset_ns2 = df2.copy()
dataset_ns3 = df3.copy()

# %%
imputer_mean = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
imputer_modus = SimpleImputer(strategy='most_frequent')

# %% [markdown]
# # Modus

# %%
dataset_ns2['opp_pf'] = imputer_modus.fit_transform(dataset_ns2[['opp_pf']])
dataset_ns2.isna().sum()
# Out:
# team_name     0
# game_num      0
# date          0
# site          0
# opp_name      0
# w_l           0
# pts           0
# opp_pts       0
# fg            0
# fga           0
# fg_per        0
# 3p            0
# 3pa           0
# 3p_per        0
# ft            0
# fta           0
# ft_per        0
# orb           0
# trb           0
# ast           0
# stl           0
# blk           0
# tov           0
# pf            0
# opp_fg        2
# opp_fga       2
# opp_fg_per    2
# opp_3p        2
# opp_3pa       2
# opp_3p_per    2
# opp_ft        2
# opp_fta       2
# opp_ft_per    2
# opp_orb       2
# opp_trb       2
# opp_ast       2
# opp_stl       2
# opp_blk       2
# opp_tov       2
# opp_pf        0
# dtype: int64

# %% [markdown]
# # mean

# %%
dataset_ns2['opp_stl'] = imputer_mean.fit_transform(dataset_ns2[['opp_stl']])

dataset_ns2.isna().sum()
# Out:
# team_name     0
# game_num      0
# date          0
# site          0
# opp_name      0
# w_l           0
# pts           0
# opp_pts       0
# fg            0
# fga           0
# fg_per        0
# 3p            0
# 3pa           0
# 3p_per        0
# ft            0
# fta           0
# ft_per        0
# orb           0
# trb           0
# ast           0
# stl           0
# blk           0
# tov           0
# pf            0
# opp_fg        2
# opp_fga       2
# opp_fg_per    2
# opp_3p        2
# opp_3pa       2
# opp_3p_per    2
# opp_ft        2
# opp_fta       2
# opp_ft_per    2
# opp_orb       2
# opp_trb       2
# opp_ast       2
# opp_stl       0
# opp_blk       2
# opp_tov       2
# opp_pf        0
# dtype: int64

# %%
dataset_ns2.dropna(inplace=True)

dataset_ns2.isna().sum()
# Out:
# team_name     0
# game_num      0
# date          0
# site          0
# opp_name      0
# w_l           0
# pts           0
# opp_pts       0
# fg            0
# fga           0
# fg_per        0
# 3p            0
# 3pa           0
# 3p_per        0
# ft            0
# fta           0
# ft_per        0
# orb           0
# trb           0
# ast           0
# stl           0
# blk           0
# tov           0
# pf            0
# opp_fg        0
# opp_fga       0
# opp_fg_per    0
# opp_3p        0
# opp_3pa       0
# opp_3p_per    0
# opp_ft        0
# opp_fta       0
# opp_ft_per    0
# opp_orb       0
# opp_trb       0
# opp_ast       0
# opp_stl       0
# opp_blk       0
# opp_tov       0
# opp_pf        0
# dtype: int64

# %% [markdown]
# # Data Duplicate

# %%
dataset_duplicate = df3.copy()

dataset_duplicate.duplicated().sum()
# Out:
# 16

# %%
dataset_duplicate.drop_duplicates(inplace=True)

dataset_duplicate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #  K-MEANS

# %%
dataset_ns2.head()
# Out:
#                     team_name  game_num        date  site         opp_name  \
# 0  Abilene Christian Wildcats         1  2013-11-09  Away         Duquesne
# 1  Abilene Christian Wildcats         2  2013-11-11  Away  St. Bonaventure
# 2  Abilene Christian Wildcats         3  2013-11-13  Away         Maryland
# 3  Abilene Christian Wildcats         4  2013-11-17  Away             Iowa
# 4  Abilene Christian Wildcats         5  2013-11-19  Away              TCU
#
#   w_l pts  opp_pts  fg  fga  ...  opp_ft  opp_fta  opp_ft_per  opp_orb  \
# 0   L  75       94  22   63  ...    27.0   37.000       0.730     10.0
# 1   L  47       75  14   40  ...    23.0   32.000       0.719     18.0
# 2   L  44       67  17   54  ...    17.0    0.647      12.000     38.0
# 3   L  41      103  14   54  ...    18.0   22.000       0.818      5.0
# 4   L  64       71  19   50  ...    24.0   37.000       0.649      8.0
#
#    opp_trb  opp_ast  opp_stl  opp_blk  opp_tov  opp_pf
# 0     40.0     19.0      4.0      2.0     10.0    22.0
# 1     40.0     15.0      7.0      7.0      9.0    23.0
# 2     12.0      9.0     10.0     17.0      8.0    18.0
# 3     35.0     25.0     11.0      5.0      5.0    10.0
# 4     30.0     11.0      7.0      3.0      6.0    20.0
#
# [5 rows x 40 columns]

# %%
dataset_ns2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90966 entries, 0 to 90967
# Data columns (total 40 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   team_name   90966 non-null  object
#  1   game_num    90966 non-null  int64
#  2   date        90966 non-null  object
#  3   site        90966 non-null  object
#  4   opp_name    90966 non-null  object
#  5   w_l         90966 non-null  object
#  6   pts         90966 non-null  object
#  7   opp_pts     90966 non-null  int64
#  8   fg          90966 non-null  int64
#  9   fga         90966 non-null  int64
#  10  fg_per      90966 non-null  float64
#  11  3p          90966 non-null  float64
#  12  3pa         90966 non-null  int64
#  13  3p_per      90966 non-null  float64
#  14  ft          90966 non-null  float64
#  15  fta         90966 non-null  int64
#  16  ft_per      90966 non-null  float64
#  17  orb         90966 non-null  float64
#  18  trb         90966 non-null  int64
#  19  ast         90966 non-null  int64
#  20  stl         90966 non-null  int64
#  21  blk         90966 non-null  int64
#  22  tov         90966 non-null  int64
#  23  pf          90966 non-null  int64
#  24  opp_fg      90966 non-null  float64
#  25  opp_fga     90966 non-null  float64
#  26  opp_fg_per  90966 non-null  float64
#  27  opp_3p      90966 non-null  float64
#  28  opp_3pa     90966 non-null  float64
#  29  opp_3p_per  90966 non-null  float64
#  30  opp_ft      90966 non-null  float64
#  31  opp_fta     90966 non-null  float64
#  32  opp_ft_per  90966 non-null  float64
#  33  opp_orb     90966 non-null  float64
#  34  opp_trb     90966 non-null  float64
#  35  opp_ast     90966 non-null  float64
#  36  opp_stl     90966 non-null  float64
#  37  opp_blk     90966 non-null  float64
#  38  opp_tov     90966 non-null  float64
#  39  opp_pf      90966 non-null  float64
# dtypes: float64(22), int64(12), object(6)
# memory usage: 28.5+ MB

# %%
model = KMeans(n_clusters=4)

# %%
point = dataset_ns2[['opp_pf','opp_3p']]

# %%
model.fit(point)
# Out:
# KMeans(n_clusters=4)

# %%
label = model.labels_

# %%
label
# Out:
# array([3, 1, 2, ..., 0, 2, 1])

# %%
X = point['opp_pf']
Y = point['opp_3p']

# %%
centroid = model.cluster_centers_

# %%
centroid
# Out:
# array([[13.55634858,  6.09464823],
#        [19.16876705,  4.6353636 ],
#        [18.46832311, 10.349451  ],
#        [25.27557411,  6.70018557]])

# %%
centroid_X = centroid[:,0]
centroid_Y = centroid[:,1]

# %%
predicted_value = classifier.predict(x_test)
accuracy = accuracy_score(y_test, predicted_value)

# %%
plt.figure(figsize=(5,5))
plt.scatter(X, Y, alpha=0.5, c=label)
plt.scatter(centroid_X, centroid_Y, marker='D', s=50, label='centroid')
plt.xlabel('opp_pf')
plt.ylabel('opp_3p')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [31], line 3
#       1 plt.figure(figsize=(5,5))
#       2 plt.scatter(X, Y, alpha=0.5, c=label)
# ----> 3 plt.scatter(centroid_X, centroid_Y, marker='D', s=50, label='centroid')
#       4 plt.xlabel('opp_pf')
#       5 plt.ylabel('opp_3p')
#
# NameError: name 'centroid_X' is not defined

# %%
cluster_range = range(1,6)
inertias = []

for k in cluster_range:
    model = KMeans(n_clusters=k)
    model.fit(point)
    inertias.append(model.inertia_)

# %%
plt.figure(figsize=(5,5))
plt.plot(cluster_range, inertias, '-o')
plt.xlabel('Cluster ke-')
plt.ylabel('Inertia/Sum Square Error')
plt.xticks(cluster_range)
plt.show()
